# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/P_Data_Extract_From_World_Development_Indicators/0bcc63a9-526c-4673-98ef-4f8ebcf0fe7c_Data.csv')

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#   1989 [YR1989] 1990 [YR1990] 1991 [YR1991] 1992 [YR1992] 1993 [YR1993]  \
# 0            ..            ..            ..            ..            ..
# 1            ..            ..            ..            ..            ..
# 2            ..            ..            ..            ..            ..
# 3            ..            ..            ..            ..            ..
# 4            ..            ..            ..            ..            ..
#
#   1994 [YR1994]  ... 2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# 0            ..  ...          26.1          27.6          28.8          30.3
# 1            ..  ...          10.2          11.4          12.6          13.5
# 2            ..  ...            78          79.5          80.5          81.6
# 3            ..  ...          89.5          71.5          97.7          97.7
# 4            ..  ...          86.5          64.6          97.1          97.1
#
#   2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021] 2022 [YR2022]  \
# 0          31.4          32.6          33.8          34.9          36.1
# 1          14.5          15.6          16.4          17.4          18.5
# 2          82.6          83.2          83.8          84.5            85
# 3          93.4          97.7          97.7          97.7          85.3
# 4          91.6          97.1          97.1          97.1          81.7
#
#   2023 [YR2023]
# 0            ..
# 1            ..
# 2            ..
# 3            ..
# 4            ..
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24211 entries, 0 to 24210
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   24208 non-null  object
#  1   Country Code   24206 non-null  object
#  2   Series Name    24206 non-null  object
#  3   Series Code    24206 non-null  object
#  4   1989 [YR1989]  24206 non-null  object
#  5   1990 [YR1990]  24206 non-null  object
#  6   1991 [YR1991]  24206 non-null  object
#  7   1992 [YR1992]  24206 non-null  object
#  8   1993 [YR1993]  24206 non-null  object
#  9   1994 [YR1994]  24206 non-null  object
#  10  1995 [YR1995]  24206 non-null  object
#  11  1996 [YR1996]  24206 non-null  object
#  12  1997 [YR1997]  24206 non-null  object
#  13  1998 [YR1998]  24206 non-null  object
#  14  1999 [YR1999]  24206 non-null  object
#  15  2000 [YR2000]  24206 non-null  object
#  16  2001 [YR2001]  24206 non-null  object
#  17  2002 [YR2002]  24206 non-null  object
#  18  2003 [YR2003]  24206 non-null  object
#  19  2004 [YR2004]  24206 non-null  object
#  20  2005 [YR2005]  24206 non-null  object
#  21  2006 [YR2006]  24206 non-null  object
#  22  2007 [YR2007]  24206 non-null  object
#  23  2008 [YR2008]  24206 non-null  object
#  24  2009 [YR2009]  24206 non-null  object
#  25  2010 [YR2010]  24206 non-null  object
#  26  2011 [YR2011]  24206 non-null  object
#  27  2012 [YR2012]  24206 non-null  object
#  28  2013 [YR2013]  24206 non-null  object
#  29  2014 [YR2014]  24206 non-null  object
#  30  2015 [YR2015]  24206 non-null  object
#  31  2016 [YR2016]  24206 non-null  object
#  32  2017 [YR2017]  24206 non-null  object
#  33  2018 [YR2018]  24206 non-null  object
#  34  2019 [YR2019]  24206 non-null  object
#  35  2020 [YR2020]  24206 non-null  object
#  36  2021 [YR2021]  24206 non-null  object
#  37  2022 [YR2022]  24206 non-null  object
#  38  2023 [YR2023]  24206 non-null  object
# dtypes: object(39)
# memory usage: 7.2+ MB

# %%
df.shape
# Out:
# (24211, 39)

# %%
df.isnull().sum()
# Out:
# Country Name     3
# Country Code     5
# Series Name      5
# Series Code      5
# 1989 [YR1989]    5
# 1990 [YR1990]    5
# 1991 [YR1991]    5
# 1992 [YR1992]    5
# 1993 [YR1993]    5
# 1994 [YR1994]    5
# 1995 [YR1995]    5
# 1996 [YR1996]    5
# 1997 [YR1997]    5
# 1998 [YR1998]    5
# 1999 [YR1999]    5
# 2000 [YR2000]    5
# 2001 [YR2001]    5
# 2002 [YR2002]    5
# 2003 [YR2003]    5
# 2004 [YR2004]    5
# 2005 [YR2005]    5
# 2006 [YR2006]    5
# 2007 [YR2007]    5
# 2008 [YR2008]    5
# 2009 [YR2009]    5
# 2010 [YR2010]    5
# 2011 [YR2011]    5
# 2012 [YR2012]    5
# 2013 [YR2013]    5
# 2014 [YR2014]    5
# 2015 [YR2015]    5
# 2016 [YR2016]    5
# 2017 [YR2017]    5
# 2018 [YR2018]    5
# 2019 [YR2019]    5
# 2020 [YR2020]    5
# 2021 [YR2021]    5
# 2022 [YR2022]    5
# 2023 [YR2023]    5
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]',
#        '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]',
#        '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]',
#        '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]',
#        '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]',
#        '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]',
#        '2021 [YR2021]', '2022 [YR2022]', '2023 [YR2023]'],
#       dtype='object')

# %%
series_name = df['Series Name'].value_counts()

print(series_name)
# Out:
# Series Name
# Access to clean fuels and technologies for cooking (% of population)     266
# Methane (CH4) emissions from Waste (Mt CO2e)                             266
# Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)           266
# Methane (CH4) emissions from Industrial Processes (Mt CO2e)              266
# Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)    266
#                                                                         ...
# Electric power transmission and distribution losses (% of output)        266
# Electric power consumption (kWh per capita)                              266
# Combustible renewables and waste (% of total energy)                     266
# Carbon intensity of GDP (kg CO2e per constant 2015 US$ of GDP)           266
# Total greenhouse gas emissions including LULUCF (Mt CO2e)                266
# Name: count, Length: 91, dtype: int64

# %%
df['Country Name'].value_counts()
# Out:
# Country Name
# Afghanistan                                         91
# St. Martin (French part)                            91
# Seychelles                                          91
# Sierra Leone                                        91
# Singapore                                           91
#                                                     ..
# Israel                                              91
# Italy                                               91
# Jamaica                                             91
# Data from database: World Development Indicators     1
# Last Updated: 01/28/2025                             1
# Name: count, Length: 268, dtype: int64

# %%
df.replace("..", pd.NA, inplace=True)

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#   1989 [YR1989] 1990 [YR1990] 1991 [YR1991] 1992 [YR1992] 1993 [YR1993]  \
# 0          <NA>          <NA>          <NA>          <NA>          <NA>
# 1          <NA>          <NA>          <NA>          <NA>          <NA>
# 2          <NA>          <NA>          <NA>          <NA>          <NA>
# 3          <NA>          <NA>          <NA>          <NA>          <NA>
# 4          <NA>          <NA>          <NA>          <NA>          <NA>
#
#   1994 [YR1994]  ... 2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# 0          <NA>  ...          26.1          27.6          28.8          30.3
# 1          <NA>  ...          10.2          11.4          12.6          13.5
# 2          <NA>  ...            78          79.5          80.5          81.6
# 3          <NA>  ...          89.5          71.5          97.7          97.7
# 4          <NA>  ...          86.5          64.6          97.1          97.1
#
#   2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021] 2022 [YR2022]  \
# 0          31.4          32.6          33.8          34.9          36.1
# 1          14.5          15.6          16.4          17.4          18.5
# 2          82.6          83.2          83.8          84.5            85
# 3          93.4          97.7          97.7          97.7          85.3
# 4          91.6          97.1          97.1          97.1          81.7
#
#   2023 [YR2023]
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
#
# [5 rows x 39 columns]

# %%
df.isnull().sum()
# Out:
# Country Name         3
# Country Code         5
# Series Name          5
# Series Code          5
# 1989 [YR1989]    12615
# 1990 [YR1990]     9273
# 1991 [YR1991]     8941
# 1992 [YR1992]     8805
# 1993 [YR1993]     8734
# 1994 [YR1994]     8646
# 1995 [YR1995]     7713
# 1996 [YR1996]     8242
# 1997 [YR1997]     8189
# 1998 [YR1998]     8116
# 1999 [YR1999]     8081
# 2000 [YR2000]     4682
# 2001 [YR2001]     5360
# 2002 [YR2002]     5316
# 2003 [YR2003]     5225
# 2004 [YR2004]     5042
# 2005 [YR2005]     4187
# 2006 [YR2006]     4989
# 2007 [YR2007]     4905
# 2008 [YR2008]     5020
# 2009 [YR2009]     4973
# 2010 [YR2010]     4134
# 2011 [YR2011]     4062
# 2012 [YR2012]     4042
# 2013 [YR2013]     4019
# 2014 [YR2014]     4045
# 2015 [YR2015]     5562
# 2016 [YR2016]     7580
# 2017 [YR2017]     7584
# 2018 [YR2018]     8403
# 2019 [YR2019]     8417
# 2020 [YR2020]     8432
# 2021 [YR2021]    10105
# 2022 [YR2022]    10396
# 2023 [YR2023]    12629
# dtype: int64

# %%
# Selecting only year columns
year_columns = df.columns[4:]
df[year_columns] = df[year_columns].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24211 entries, 0 to 24210
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   24208 non-null  object
#  1   Country Code   24206 non-null  object
#  2   Series Name    24206 non-null  object
#  3   Series Code    24206 non-null  object
#  4   1989 [YR1989]  11596 non-null  float64
#  5   1990 [YR1990]  14938 non-null  float64
#  6   1991 [YR1991]  15270 non-null  float64
#  7   1992 [YR1992]  15406 non-null  float64
#  8   1993 [YR1993]  15477 non-null  float64
#  9   1994 [YR1994]  15565 non-null  float64
#  10  1995 [YR1995]  16498 non-null  float64
#  11  1996 [YR1996]  15969 non-null  float64
#  12  1997 [YR1997]  16022 non-null  float64
#  13  1998 [YR1998]  16095 non-null  float64
#  14  1999 [YR1999]  16130 non-null  float64
#  15  2000 [YR2000]  19529 non-null  float64
#  16  2001 [YR2001]  18851 non-null  float64
#  17  2002 [YR2002]  18895 non-null  float64
#  18  2003 [YR2003]  18986 non-null  float64
#  19  2004 [YR2004]  19169 non-null  float64
#  20  2005 [YR2005]  20024 non-null  float64
#  21  2006 [YR2006]  19222 non-null  float64
#  22  2007 [YR2007]  19306 non-null  float64
#  23  2008 [YR2008]  19191 non-null  float64
#  24  2009 [YR2009]  19238 non-null  float64
#  25  2010 [YR2010]  20077 non-null  float64
#  26  2011 [YR2011]  20149 non-null  float64
#  27  2012 [YR2012]  20169 non-null  float64
#  28  2013 [YR2013]  20192 non-null  float64
#  29  2014 [YR2014]  20166 non-null  float64
#  30  2015 [YR2015]  18649 non-null  float64
#  31  2016 [YR2016]  16631 non-null  float64
#  32  2017 [YR2017]  16627 non-null  float64
#  33  2018 [YR2018]  15808 non-null  float64
#  34  2019 [YR2019]  15794 non-null  float64
#  35  2020 [YR2020]  15779 non-null  float64
#  36  2021 [YR2021]  14106 non-null  float64
#  37  2022 [YR2022]  13815 non-null  float64
#  38  2023 [YR2023]  11582 non-null  float64
# dtypes: float64(35), object(4)
# memory usage: 7.2+ MB

# %%
df[year_columns] = df.groupby(["Country Name", "Series Name"])[year_columns].ffill()
df[year_columns] = df.groupby(["Country Name", "Series Name"])[year_columns].bfill()

# %%
df.isnull().sum()
# Out:
# Country Name         3
# Country Code         5
# Series Name          5
# Series Code          5
# 1989 [YR1989]    12615
# 1990 [YR1990]     9273
# 1991 [YR1991]     8941
# 1992 [YR1992]     8805
# 1993 [YR1993]     8734
# 1994 [YR1994]     8646
# 1995 [YR1995]     7713
# 1996 [YR1996]     8242
# 1997 [YR1997]     8189
# 1998 [YR1998]     8116
# 1999 [YR1999]     8081
# 2000 [YR2000]     4682
# 2001 [YR2001]     5360
# 2002 [YR2002]     5316
# 2003 [YR2003]     5225
# 2004 [YR2004]     5042
# 2005 [YR2005]     4187
# 2006 [YR2006]     4989
# 2007 [YR2007]     4905
# 2008 [YR2008]     5020
# 2009 [YR2009]     4973
# 2010 [YR2010]     4134
# 2011 [YR2011]     4062
# 2012 [YR2012]     4042
# 2013 [YR2013]     4019
# 2014 [YR2014]     4045
# 2015 [YR2015]     5562
# 2016 [YR2016]     7580
# 2017 [YR2017]     7584
# 2018 [YR2018]     8403
# 2019 [YR2019]     8417
# 2020 [YR2020]     8432
# 2021 [YR2021]    10105
# 2022 [YR2022]    10396
# 2023 [YR2023]    12629
# dtype: int64

# %%
missing_threshold = 0.5 * len(year_columns)
df = df.dropna(thresh=missing_threshold, axis=0)

# %%
df.shape
# Out:
# (19243, 39)

# %%
df[year_columns] = df[year_columns].apply(lambda x: x.fillna(x.mean()), axis=0)

# %%
df.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# Series Name      0
# Series Code      0
# 1989 [YR1989]    0
# 1990 [YR1990]    0
# 1991 [YR1991]    0
# 1992 [YR1992]    0
# 1993 [YR1993]    0
# 1994 [YR1994]    0
# 1995 [YR1995]    0
# 1996 [YR1996]    0
# 1997 [YR1997]    0
# 1998 [YR1998]    0
# 1999 [YR1999]    0
# 2000 [YR2000]    0
# 2001 [YR2001]    0
# 2002 [YR2002]    0
# 2003 [YR2003]    0
# 2004 [YR2004]    0
# 2005 [YR2005]    0
# 2006 [YR2006]    0
# 2007 [YR2007]    0
# 2008 [YR2008]    0
# 2009 [YR2009]    0
# 2010 [YR2010]    0
# 2011 [YR2011]    0
# 2012 [YR2012]    0
# 2013 [YR2013]    0
# 2014 [YR2014]    0
# 2015 [YR2015]    0
# 2016 [YR2016]    0
# 2017 [YR2017]    0
# 2018 [YR2018]    0
# 2019 [YR2019]    0
# 2020 [YR2020]    0
# 2021 [YR2021]    0
# 2022 [YR2022]    0
# 2023 [YR2023]    0
# dtype: int64

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#    1989 [YR1989]  1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  \
# 0   7.707894e+07   7.737844e+07   5.953423e+07   6.544516e+07   6.746293e+07
# 1   7.707894e+07   7.737844e+07   5.953423e+07   6.544516e+07   6.746293e+07
# 2   7.707894e+07   7.737844e+07   5.953423e+07   6.544516e+07   6.746293e+07
# 3   7.707894e+07   7.737844e+07   5.953423e+07   6.544516e+07   6.746293e+07
# 4   7.707894e+07   7.737844e+07   5.953423e+07   6.544516e+07   6.746293e+07
#
#    1994 [YR1994]  ...  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0   7.090160e+07  ...           26.1           27.6           28.8
# 1   7.090160e+07  ...           10.2           11.4           12.6
# 2   7.090160e+07  ...           78.0           79.5           80.5
# 3   7.090160e+07  ...           89.5           71.5           97.7
# 4   7.090160e+07  ...           86.5           64.6           97.1
#
#    2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  2021 [YR2021]  \
# 0           30.3           31.4           32.6           33.8           34.9
# 1           13.5           14.5           15.6           16.4           17.4
# 2           81.6           82.6           83.2           83.8           84.5
# 3           97.7           93.4           97.7           97.7           97.7
# 4           97.1           91.6           97.1           97.1           97.1
#
#    2022 [YR2022]  2023 [YR2023]
# 0           36.1     154.506541
# 1           18.5     154.506541
# 2           85.0     154.506541
# 3           85.3     154.506541
# 4           81.7     154.506541
#
# [5 rows x 39 columns]

# %%
df.columns = [col.replace(" [YR", "_").replace("]", "") if "YR" in col else col for col in df.columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#       1989_1989     1990_1990     1991_1991     1992_1992     1993_1993  \
# 0  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 1  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 2  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 3  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 4  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
#
#       1994_1994  ...  2014_2014  2015_2015  2016_2016  2017_2017  2018_2018  \
# 0  7.090160e+07  ...       26.1       27.6       28.8       30.3       31.4
# 1  7.090160e+07  ...       10.2       11.4       12.6       13.5       14.5
# 2  7.090160e+07  ...       78.0       79.5       80.5       81.6       82.6
# 3  7.090160e+07  ...       89.5       71.5       97.7       97.7       93.4
# 4  7.090160e+07  ...       86.5       64.6       97.1       97.1       91.6
#
#    2019_2019  2020_2020  2021_2021  2022_2022   2023_2023
# 0       32.6       33.8       34.9       36.1  154.506541
# 1       15.6       16.4       17.4       18.5  154.506541
# 2       83.2       83.8       84.5       85.0  154.506541
# 3       97.7       97.7       97.7       85.3  154.506541
# 4       97.1       97.1       97.1       81.7  154.506541
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (19243, 39)

# %%
df.to_csv('../datasets/cleaned_dataset.csv')

# %%
url = "https://databank.worldbank.org/data/download/site-content/CLASS.xlsx"

column_names = ["Country Name", "Country Code", "Region", "Income Level", "Lending Category", "Extra"]

income_df = pd.read_excel(url, sheet_name="List of economies", skiprows=3, header=None,  names=column_names)

# %%
income_df.tail(100)
# Out:
#                                    Country Name Country Code  \
# 163                          Russian Federation          RUS
# 164                                      Rwanda          RWA
# 165                                Saudi Arabia          SAU
# 166                                       Sudan          SDN
# 167                                     Senegal          SEN
# ..                                          ...          ...
# 258                          Sub-Saharan Africa          SSF
# 259  Sub-Saharan Africa (excluding high income)          SSA
# 260             Sub-Saharan Africa (IDA & IBRD)          TSS
# 261                         Upper middle income          UMC
# 262                                       World          WLD
#
#                          Region         Income Level Lending Category Extra
# 163       Europe & Central Asia  Upper middle income             IBRD   NaN
# 164          Sub-Saharan Africa           Low income              IDA  HIPC
# 165  Middle East & North Africa          High income              NaN   NaN
# 166          Sub-Saharan Africa           Low income              IDA  HIPC
# 167          Sub-Saharan Africa  Lower middle income              IDA  HIPC
# ..                          ...                  ...              ...   ...
# 258                         NaN                  NaN              NaN   NaN
# 259                         NaN                  NaN              NaN   NaN
# 260                         NaN                  NaN              NaN   NaN
# 261                         NaN                  NaN              NaN   NaN
# 262                         NaN                  NaN              NaN   NaN
#
# [100 rows x 6 columns]

# %%
income_df = income_df[["Country Name", "Region", "Income Level"]]

# %%
income_df = income_df[income_df["Income Level"].isin(["Low income", "Lower middle income", "Upper middle income"])]

# %%
growth_rates_emissions_energy_prod_income_level_country_df = df.merge(income_df, on="Country Name", how="left")

# %%
growth_rates_emissions_energy_prod_income_level_country_df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#       1989_1989     1990_1990     1991_1991     1992_1992     1993_1993  \
# 0  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 1  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 2  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 3  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
# 4  7.707894e+07  7.737844e+07  5.953423e+07  6.544516e+07  6.746293e+07
#
#       1994_1994  ...  2016_2016  2017_2017  2018_2018  2019_2019  2020_2020  \
# 0  7.090160e+07  ...       28.8       30.3       31.4       32.6       33.8
# 1  7.090160e+07  ...       12.6       13.5       14.5       15.6       16.4
# 2  7.090160e+07  ...       80.5       81.6       82.6       83.2       83.8
# 3  7.090160e+07  ...       97.7       97.7       93.4       97.7       97.7
# 4  7.090160e+07  ...       97.1       97.1       91.6       97.1       97.1
#
#    2021_2021  2022_2022   2023_2023  Region  Income Level
# 0       34.9       36.1  154.506541     NaN           NaN
# 1       17.4       18.5  154.506541     NaN           NaN
# 2       84.5       85.0  154.506541     NaN           NaN
# 3       97.7       85.3  154.506541     NaN           NaN
# 4       97.1       81.7  154.506541     NaN           NaN
#
# [5 rows x 41 columns]

# %%
print(growth_rates_emissions_energy_prod_income_level_country_df["Income Level"].value_counts())
# Out:
# Income Level
# Upper middle income    3872
# Lower middle income    3863
# Low income             1818
# Name: count, dtype: int64

# %%
missing_countries = growth_rates_emissions_energy_prod_income_level_country_df[growth_rates_emissions_energy_prod_income_level_country_df["Income Level"].isna()]["Country Name"].unique()
print("Countries with missing income classification:", missing_countries)
# Out:
# Countries with missing income classification: ['Afghanistan' 'Andorra' 'Antigua and Barbuda' 'Aruba' 'Australia'
#  'Austria' 'Bahamas, The' 'Bahrain' 'Barbados' 'Belgium' 'Bermuda'
#  'British Virgin Islands' 'Brunei Darussalam' 'Canada' 'Cayman Islands'
#  'Channel Islands' 'Chile' "Cote d'Ivoire" 'Croatia' 'Curacao' 'Cyprus'
#  'Czechia' 'Denmark' 'Estonia' 'Faroe Islands' 'Finland' 'France'
#  'French Polynesia' 'Germany' 'Gibraltar' 'Greece' 'Greenland' 'Guam'
#  'Hong Kong SAR, China' 'Hungary' 'Iceland' 'Ireland' 'Isle of Man'
#  'Israel' 'Italy' 'Japan' 'Korea, Rep.' 'Kuwait' 'Latvia' 'Liechtenstein'
#  'Lithuania' 'Luxembourg' 'Macao SAR, China' 'Malta' 'Monaco' 'Nauru'
#  'Netherlands' 'New Caledonia' 'New Zealand' 'Northern Mariana Islands'
#  'Norway' 'Oman' 'Panama' 'Poland' 'Portugal' 'Puerto Rico' 'Qatar'
#  'Romania' 'San Marino' 'Sao Tome and Principe' 'Saudi Arabia'
#  'Seychelles' 'Singapore' 'Sint Maarten (Dutch part)' 'Slovak Republic'
#  'Slovenia' 'Spain' 'St. Kitts and Nevis' 'St. Martin (French part)'
#  'Sweden' 'Switzerland' 'Trinidad and Tobago' 'Turkiye'
#  'Turks and Caicos Islands' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'Uruguay' 'Venezuela, RB' 'Viet Nam'
#  'Virgin Islands (U.S.)' 'Africa Eastern and Southern'
#  'Africa Western and Central' 'Arab World' 'Caribbean small states'
#  'Central Europe and the Baltics' 'Early-demographic dividend'
#  'East Asia & Pacific' 'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD countries)' 'Euro area'
#  'Europe & Central Asia' 'Europe & Central Asia (excluding high income)'
#  'Europe & Central Asia (IDA & IBRD countries)' 'European Union'
#  'Fragile and conflict affected situations'
#  'Heavily indebted poor countries (HIPC)' 'High income' 'IBRD only'
#  'IDA & IBRD total' 'IDA blend' 'IDA only' 'IDA total'
#  'Late-demographic dividend' 'Latin America & Caribbean'
#  'Latin America & Caribbean (excluding high income)'
#  'Latin America & the Caribbean (IDA & IBRD countries)'
#  'Least developed countries: UN classification' 'Low & middle income'
#  'Low income' 'Lower middle income' 'Middle East & North Africa'
#  'Middle East & North Africa (excluding high income)'
#  'Middle East & North Africa (IDA & IBRD countries)' 'Middle income'
#  'North America' 'OECD members' 'Other small states'
#  'Pacific island small states' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'Small states' 'South Asia'
#  'South Asia (IDA & IBRD)' 'Sub-Saharan Africa'
#  'Sub-Saharan Africa (excluding high income)'
#  'Sub-Saharan Africa (IDA & IBRD countries)' 'Upper middle income' 'World']

# %%
regions_to_remove = [
    "World", "Sub-Saharan Africa", "OECD members", "East Asia & Pacific", "Europe & Central Asia",
    "Middle East & North Africa", "Latin America & Caribbean", "South Asia", "North America",
    "Fragile and conflict affected situations", "Least developed countries: UN classification",
    "Low & middle income", "Lower middle income", "Middle income", "Upper middle income",
    "Heavily indebted poor countries (HIPC)", "Small states", "IBRD only", "IDA & IBRD total",
    "IDA blend", "IDA only", "IDA total", "Euro area", "European Union",
    "East Asia & Pacific (IDA & IBRD countries)", "Europe & Central Asia (IDA & IBRD countries)",
    "Latin America & the Caribbean (IDA & IBRD countries)",
    "Middle East & North Africa (IDA & IBRD countries)", "Sub-Saharan Africa (IDA & IBRD countries)"
]

growth_rates_emissions_energy_prod_income_level_country_df = growth_rates_emissions_energy_prod_income_level_country_df[
    ~growth_rates_emissions_energy_prod_income_level_country_df["Country Name"].isin(regions_to_remove)
]

print("Remaining unique countries:", growth_rates_emissions_energy_prod_income_level_country_df["Country Name"].nunique())
# Out:
# Remaining unique countries: 236

# %%
missing_countries = growth_rates_emissions_energy_prod_income_level_country_df[
    growth_rates_emissions_energy_prod_income_level_country_df["Income Level"].isna()
]["Country Name"].unique()

print("Low/Middle-Income Countries with Missing Income Classification:", missing_countries)
# Out:
# Low/Middle-Income Countries with Missing Income Classification: ['Afghanistan' 'Andorra' 'Antigua and Barbuda' 'Aruba' 'Australia'
#  'Austria' 'Bahamas, The' 'Bahrain' 'Barbados' 'Belgium' 'Bermuda'
#  'British Virgin Islands' 'Brunei Darussalam' 'Canada' 'Cayman Islands'
#  'Channel Islands' 'Chile' "Cote d'Ivoire" 'Croatia' 'Curacao' 'Cyprus'
#  'Czechia' 'Denmark' 'Estonia' 'Faroe Islands' 'Finland' 'France'
#  'French Polynesia' 'Germany' 'Gibraltar' 'Greece' 'Greenland' 'Guam'
#  'Hong Kong SAR, China' 'Hungary' 'Iceland' 'Ireland' 'Isle of Man'
#  'Israel' 'Italy' 'Japan' 'Korea, Rep.' 'Kuwait' 'Latvia' 'Liechtenstein'
#  'Lithuania' 'Luxembourg' 'Macao SAR, China' 'Malta' 'Monaco' 'Nauru'
#  'Netherlands' 'New Caledonia' 'New Zealand' 'Northern Mariana Islands'
#  'Norway' 'Oman' 'Panama' 'Poland' 'Portugal' 'Puerto Rico' 'Qatar'
#  'Romania' 'San Marino' 'Sao Tome and Principe' 'Saudi Arabia'
#  'Seychelles' 'Singapore' 'Sint Maarten (Dutch part)' 'Slovak Republic'
#  'Slovenia' 'Spain' 'St. Kitts and Nevis' 'St. Martin (French part)'
#  'Sweden' 'Switzerland' 'Trinidad and Tobago' 'Turkiye'
#  'Turks and Caicos Islands' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'Uruguay' 'Venezuela, RB' 'Viet Nam'
#  'Virgin Islands (U.S.)' 'Africa Eastern and Southern'
#  'Africa Western and Central' 'Arab World' 'Caribbean small states'
#  'Central Europe and the Baltics' 'Early-demographic dividend'
#  'East Asia & Pacific (excluding high income)'
#  'Europe & Central Asia (excluding high income)' 'High income'
#  'Late-demographic dividend'
#  'Latin America & Caribbean (excluding high income)' 'Low income'
#  'Middle East & North Africa (excluding high income)' 'Other small states'
#  'Pacific island small states' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'South Asia (IDA & IBRD)'
#  'Sub-Saharan Africa (excluding high income)']

# %%
high_income_and_regions = [
    "Andorra", "Australia", "Austria", "Bahamas, The", "Bahrain", "Barbados", "Belgium", "Bermuda",
    "Brunei Darussalam", "Canada", "Cayman Islands", "Channel Islands", "Cyprus", "Czechia",
    "Denmark", "Estonia", "Faroe Islands", "Finland", "France", "French Polynesia", "Germany",
    "Gibraltar", "Greece", "Greenland", "Guam", "Hong Kong SAR, China", "Hungary", "Iceland",
    "Ireland", "Isle of Man", "Israel", "Italy", "Japan", "Korea, Rep.", "Kuwait", "Latvia",
    "Liechtenstein", "Lithuania", "Luxembourg", "Macao SAR, China", "Malta", "Monaco", "Netherlands",
    "New Caledonia", "New Zealand", "Northern Mariana Islands", "Norway", "Oman", "Poland",
    "Portugal", "Puerto Rico", "Qatar", "San Marino", "Saudi Arabia", "Seychelles", "Singapore",
    "Sint Maarten (Dutch part)", "Slovak Republic", "Slovenia", "Spain", "St. Kitts and Nevis",
    "St. Martin (French part)", "Sweden", "Switzerland", "Trinidad and Tobago", "United Arab Emirates",
    "United Kingdom", "United States", 
    "Africa Eastern and Southern", "Africa Western and Central", "Arab World", "Caribbean small states",
    "Central Europe and the Baltics", "Early-demographic dividend", "East Asia & Pacific (excluding high income)",
    "Europe & Central Asia (excluding high income)", "High income", "Late-demographic dividend",
    "Latin America & Caribbean (excluding high income)", "Low income", "Middle East & North Africa (excluding high income)",
    "Other small states", "Pacific island small states", "Post-demographic dividend",
    "Pre-demographic dividend", "South Asia (IDA & IBRD)", "Sub-Saharan Africa (excluding high income)"
]

growth_rates_emissions_energy_prod_income_level_country_df = growth_rates_emissions_energy_prod_income_level_country_df[
    ~growth_rates_emissions_energy_prod_income_level_country_df["Country Name"].isin(high_income_and_regions)
]

missing_countries = growth_rates_emissions_energy_prod_income_level_country_df[
    growth_rates_emissions_energy_prod_income_level_country_df["Income Level"].isna()
]["Country Name"].unique()

print("missing countries:", missing_countries)
# Out:
# missing countries: ['Afghanistan' 'Antigua and Barbuda' 'Aruba' 'British Virgin Islands'
#  'Chile' "Cote d'Ivoire" 'Croatia' 'Curacao' 'Nauru' 'Panama' 'Romania'
#  'Sao Tome and Principe' 'Turkiye' 'Turks and Caicos Islands' 'Uruguay'
#  'Venezuela, RB' 'Viet Nam' 'Virgin Islands (U.S.)']

# %%
manual_income_levels = {
    "Cote d'Ivoire": "Lower middle income",
    "Sao Tome and Principe": "Lower middle income",
    "Turkiye": "Upper middle income",
    "Viet Nam": "Lower middle income",
    "Afghanistan": "Low income",
    "Antigua and Barbuda": "High income",
    "Aruba": "High income",
    "Chile": "High income",
    "Croatia": "High income",
    "Curacao": "High income",
    "Panama": "Upper middle income",
    "Romania": "Upper middle income",
    "Uruguay": "High income",
    "Venezuela, RB": "Upper middle income"
}

growth_rates_emissions_energy_prod_income_level_country_df["Income Level"] = growth_rates_emissions_energy_prod_income_level_country_df[
    "Country Name"
].map(manual_income_levels).fillna(growth_rates_emissions_energy_prod_income_level_country_df["Income Level"])

missing_countries_final = growth_rates_emissions_energy_prod_income_level_country_df[
    growth_rates_emissions_energy_prod_income_level_country_df["Income Level"].isna()
]["Country Name"].unique()

print("Final missing countries:", missing_countries_final)
# Out:
# Final missing countries: ['British Virgin Islands' 'Nauru' 'Turks and Caicos Islands'
#  'Virgin Islands (U.S.)']

# %%
high_income_territories = [
    "British Virgin Islands", "Nauru", "Turks and Caicos Islands", "Virgin Islands (U.S.)"
]

growth_rates_emissions_energy_prod_income_level_country_df = growth_rates_emissions_energy_prod_income_level_country_df[
    ~growth_rates_emissions_energy_prod_income_level_country_df["Country Name"].isin(high_income_territories)
]

missing_countries_final = growth_rates_emissions_energy_prod_income_level_country_df[
    growth_rates_emissions_energy_prod_income_level_country_df["Income Level"].isna()
]["Country Name"].unique()

print("Final missing countries:", missing_countries_final)
# Out:
# Final missing countries: []

# %%
growth_rates_emissions_energy_prod_income_level_country_df.shape
# Out:
# (10541, 41)

# %%
growth_rates_emissions_energy_prod_income_level_country_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10541 entries, 0 to 15263
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  10541 non-null  object
#  1   Country Code  10541 non-null  object
#  2   Series Name   10541 non-null  object
#  3   Series Code   10541 non-null  object
#  4   1989_1989     10541 non-null  float64
#  5   1990_1990     10541 non-null  float64
#  6   1991_1991     10541 non-null  float64
#  7   1992_1992     10541 non-null  float64
#  8   1993_1993     10541 non-null  float64
#  9   1994_1994     10541 non-null  float64
#  10  1995_1995     10541 non-null  float64
#  11  1996_1996     10541 non-null  float64
#  12  1997_1997     10541 non-null  float64
#  13  1998_1998     10541 non-null  float64
#  14  1999_1999     10541 non-null  float64
#  15  2000_2000     10541 non-null  float64
#  16  2001_2001     10541 non-null  float64
#  17  2002_2002     10541 non-null  float64
#  18  2003_2003     10541 non-null  float64
#  19  2004_2004     10541 non-null  float64
#  20  2005_2005     10541 non-null  float64
#  21  2006_2006     10541 non-null  float64
#  22  2007_2007     10541 non-null  float64
#  23  2008_2008     10541 non-null  float64
#  24  2009_2009     10541 non-null  float64
#  25  2010_2010     10541 non-null  float64
#  26  2011_2011     10541 non-null  float64
#  27  2012_2012     10541 non-null  float64
#  28  2013_2013     10541 non-null  float64
#  29  2014_2014     10541 non-null  float64
#  30  2015_2015     10541 non-null  float64
#  31  2016_2016     10541 non-null  float64
#  32  2017_2017     10541 non-null  float64
#  33  2018_2018     10541 non-null  float64
#  34  2019_2019     10541 non-null  float64
#  35  2020_2020     10541 non-null  float64
#  36  2021_2021     10541 non-null  float64
#  37  2022_2022     10541 non-null  float64
#  38  2023_2023     10541 non-null  float64
#  39  Region        9553 non-null   object
#  40  Income Level  10541 non-null  object
# dtypes: float64(35), object(6)
# memory usage: 3.4+ MB

# %%
growth_rates_emissions_energy_prod_income_level_country_df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Series Name       0
# Series Code       0
# 1989_1989         0
# 1990_1990         0
# 1991_1991         0
# 1992_1992         0
# 1993_1993         0
# 1994_1994         0
# 1995_1995         0
# 1996_1996         0
# 1997_1997         0
# 1998_1998         0
# 1999_1999         0
# 2000_2000         0
# 2001_2001         0
# 2002_2002         0
# 2003_2003         0
# 2004_2004         0
# 2005_2005         0
# 2006_2006         0
# 2007_2007         0
# 2008_2008         0
# 2009_2009         0
# 2010_2010         0
# 2011_2011         0
# 2012_2012         0
# 2013_2013         0
# 2014_2014         0
# 2015_2015         0
# 2016_2016         0
# 2017_2017         0
# 2018_2018         0
# 2019_2019         0
# 2020_2020         0
# 2021_2021         0
# 2022_2022         0
# 2023_2023         0
# Region          988
# Income Level      0
# dtype: int64
