# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/P_Data_Extract_From_World_Development_Indicators/b4939732-517f-4fbf-afd6-69ceb878202c_Data.csv')

# %%
df.head(100)
# Out:
#    Country Name Country Code  \
# 0   Afghanistan          AFG
# 1   Afghanistan          AFG
# 2   Afghanistan          AFG
# 3   Afghanistan          AFG
# 4   Afghanistan          AFG
# ..          ...          ...
# 95      Albania          ALB
# 96      Albania          ALB
# 97      Albania          ALB
# 98      Albania          ALB
# 99      Albania          ALB
#
#                                           Series Name        Series Code  \
# 0   Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1   Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2   Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 3             Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4   Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ..                                                ...                ...
# 95  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24211 entries, 0 to 24210
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   24208 non-null  object
#  1   Country Code   24206 non-null  object
#  2   Series Name    24206 non-null  object
#  3   Series Code    24206 non-null  object
#  4   2014 [YR2014]  24206 non-null  object
#  5   2015 [YR2015]  24206 non-null  object
#  6   2016 [YR2016]  24206 non-null  object
#  7   2017 [YR2017]  24206 non-null  object
#  8   2018 [YR2018]  24206 non-null  object
#  9   2019 [YR2019]  24206 non-null  object
#  10  2020 [YR2020]  24206 non-null  object
#  11  2021 [YR2021]  24206 non-null  object
#  12  2022 [YR2022]  24206 non-null  object
#  13  2023 [YR2023]  24206 non-null  object
# dtypes: object(14)
# memory usage: 2.6+ MB

# %%
df.shape
# Out:
# (24211, 14)

# %%
df.isnull().sum()
# Out:
# Country Name     3
# Country Code     5
# Series Name      5
# Series Code      5
# 2014 [YR2014]    5
# 2015 [YR2015]    5
# 2016 [YR2016]    5
# 2017 [YR2017]    5
# 2018 [YR2018]    5
# 2019 [YR2019]    5
# 2020 [YR2020]    5
# 2021 [YR2021]    5
# 2022 [YR2022]    5
# 2023 [YR2023]    5
# dtype: int64
